# %% [markdown]
# <a href="https://colab.research.google.com/github/Cabranet/cabranet-notebooks/blob/main/DataAnalysisCh3_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Plotting univariant data
# Single variant data plots

# %% [markdown]
# ##Import Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ##Create a histogram of total bill frequency

# %%
# Import the Seaborn tips dataset
tips = sns.load_dataset('tips')

# Create the figure object
fig = plt.figure()

# Create one subplot inside the figure
axes1 = fig.add_subplot(1, 1, 1)

# Create a histogram
axes1.hist(data=tips, x='total_bill', edgecolor="black", bins=10)

# Add labels
axes1.set_title('Histogram of Total Bill')
axes1.set_xlabel('Frequency')
axes1.set_ylabel('Total Bill')

# Plot the chart
plt.show()

# %% [markdown]
# ##Plotting Bivariante Data - Scatter Diagram

# %%
# Create the figure object
scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1, 1, 1)

# Make the scatter plot
axes1.scatter(data=tips, x='total_bill', y='tip')

# Add labels
axes1.set_title('Scatter Plot of Total Bill vs Tip')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip Amount')

# Plot the diagram
plt.show()

# %% [markdown]
# ##A Scatter Plot Using Seaborn

# %%
scatter, ax = plt.subplots()

sns.regplot(data=tips, x='total_bill', y='tip', ax=ax)
ax.set_title('Regression Plot of Total Bill vs Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip Amount')

plt.show()

# %% [markdown]
# #Total Bill vs Tip with Coloured and Sized Markers

# %%
# Assign the colour values for male and female tippers
colours = {
    'Female': '#f1a340',
    'Male': '#998ec3',
}

scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1, 1, 1)

axes1.scatter(
    data=tips,
    x='total_bill',
    y='tip',
    s=tips['size'] ** 2 * 10,
    c=tips['sex'].map(colours),
    alpha=0.5
)

axes1.set_title('Coloured by Sex and Sized by Tip Size')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip Amount')

scatter_plot.suptitle('Scatter Diagram of Total Bill vs Tip')

plt.show()
